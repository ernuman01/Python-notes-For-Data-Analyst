# %% [markdown]
# ### to install Libraries

# %% [markdown]
# pip install numpy

# %% [markdown]
# pip install pandas

# %% [markdown]
# pip install matplotlib  etc.

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_csv("titanic 2.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv("titanic 2.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
 df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# to get name from 0 to 9 i.e, 10.....so using slicing method

# %%
df["Name"][0:10]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
a = df["Name"][0:10]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# to get index instead of 0 to 9 i need my index so

# %%
L = ["Sana", "a2", 'a3','a4', 'a5', 'a6', 'a7', 'a8', 'a9', 'a10']

# %%
pd.Series(a, index = L)
# Out:
# Sana    NaN
# a2      NaN
# a3      NaN
# a4      NaN
# a5      NaN
# a6      NaN
# a7      NaN
# a8      NaN
# a9      NaN
# a10     NaN
# Name: Name, dtype: object

# %%
pd.Series(list(a), index = L)
# Out:
# Sana                              Braund, Mr. Owen Harris
# a2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# a3                                 Heikkinen, Miss. Laina
# a4           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# a5                               Allen, Mr. William Henry
# a6                                       Moran, Mr. James
# a7                                McCarthy, Mr. Timothy J
# a8                         Palsson, Master. Gosta Leonard
# a9      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# a10                   Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
m = pd.Series([100,200,300,400,500], index = [1,2,3,4,5])

# %%
m
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m2 = pd.Series([600,700,800,900,1000], index= [1,2,3,4,5])

# %%
m2
# Out:
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %% [markdown]
# to concatematethese m1 m2

# %%
m3 = pd.concat([m,m2])

# %%
m3
# Out:
# 1     100
# 2     200
# 3     300
# 4     400
# 5     500
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3[1]
# Out:
# 1    100
# 1    600
# dtype: int64

# %%
m*m2
# Out:
# 1     60000
# 2    140000
# 3    240000
# 4    360000
# 5    500000
# dtype: int64

# %%
m/m2
# Out:
# 1    0.166667
# 2    0.285714
# 3    0.375000
# 4    0.444444
# 5    0.500000
# dtype: float64

# %%
m%m2
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m+m2
# Out:
# 1     700
# 2     900
# 3    1100
# 4    1300
# 5    1500
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### How to delete a particular column

# %% [markdown]
# delete passenger_id

# %%
df.drop("PassengerId", axis = 1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop("Survived", axis = 1)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### to delete permanantly passengerId

# %%
df.drop("PassengerId", axis = 1, inplace = True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop("Survived", axis = 1, inplace = True)

# %%
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %% [markdown]
# # Now to delete Rows

# %%
df.drop(3)
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# 5         3                                   Moran, Mr. James    male   NaN
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %% [markdown]
# see ther is no 3 index of row and not permanently delete

# %%
df.head(4)
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S

# %%
df.drop(3, inplace = True)

# %%
df
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# 5         3                                   Moran, Mr. James    male   NaN
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %% [markdown]
# ### to get the name as index in place of 0 to ...

# %%
df.set_index("Name")
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# ...

# %% [markdown]
# to get index as Name permannatly

# %%
df
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# ...

# %%
df.set_index("Name", inplace = True)

# %%
df
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# ...

# %% [markdown]
# # Now To reset the index

# %%
df.reset_index("Name")
# Out:
#                                                   Name  Pclass     Sex   Age  \
# 0                              Braund, Mr. Owen Harris       3    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 2                               Heikkinen, Miss. Laina       3  female  26.0
# 3                             Allen, Mr. William Henry       3    male  35.0
# 4                                     Moran, Mr. James       3    male   NaN
# ..                                                 ...     ...     ...   ...
# 885                              Montvila, Rev. Juozas       2    male  27.0
# 886                       Graham, Miss. Margaret Edith       1  female  19.0
# 887           Johnston, Miss. Catherine Helen "Carrie"       3  female   NaN
# 888                              Behr, Mr. Karl Howell       1    male  26.0
# 889                                Dooley, Mr. Patrick       3    male  32.0
#
# ...

# %% [markdown]
# Now above are reset

# %% [markdown]
# ## Create a data frame uswing Dictionary

# %%
d = {"key1" : [1,2,3,4,5],
    "key2" : [6,7,8,9,10],
    "key3": [11,12,13,14,15]
    }

print(d)
# Out:
# {'key1': [1, 2, 3, 4, 5], 'key2': [6, 7, 8, 9, 10], 'key3': [11, 12, 13, 14, 15]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     6    11
# 1     2     7    12
# 2     3     8    13
# 3     4     9    14
# 4     5    10    15

# %% [markdown]
# df

# %%
df
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# ...

# %% [markdown]
# # to delete a row like NaN

# %%
df
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# ...

# %%
df.dropna()
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# McCarthy, Mr. Timothy J                                  1    male  54.0
# Sandstrom, Miss. Marguerite Rut                          3  female   4.0
# Bonnell, Miss. Elizabeth                                 1  female  58.0
# Beesley, Mr. Lawrence                                    2    male  34.0
# ...                                                    ...     ...   ...
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)         1  female  47.0
# Carlsson, Mr. Frans Olof                                 1    male  33.0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)            1  female  56.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Behr, Mr. Karl Howell                                    1    male  26.0
#
#                                                     SibSp  Parch    Ticket  \
# Name
# ...

# %% [markdown]
# now we can see that the row which has NaN is delete but not permannantly , so to delete permanantly  inplace = True

# %%
df
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# ...

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# McCarthy, Mr. Timothy J                                  1    male  54.0
# Sandstrom, Miss. Marguerite Rut                          3  female   4.0
# Bonnell, Miss. Elizabeth                                 1  female  58.0
# Beesley, Mr. Lawrence                                    2    male  34.0
# ...                                                    ...     ...   ...
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)         1  female  47.0
# Carlsson, Mr. Frans Olof                                 1    male  33.0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)            1  female  56.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Behr, Mr. Karl Howell                                    1    male  26.0
#
#                                                     SibSp  Parch    Ticket  \
# Name
# ...

# %% [markdown]
# Now we can see that rows are delte which has mising values permannaly but we can also reset it

# %% [markdown]
# # To delete column which has missing values

# %%
df
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# McCarthy, Mr. Timothy J                                  1    male  54.0
# Sandstrom, Miss. Marguerite Rut                          3  female   4.0
# Bonnell, Miss. Elizabeth                                 1  female  58.0
# Beesley, Mr. Lawrence                                    2    male  34.0
# ...                                                    ...     ...   ...
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)         1  female  47.0
# Carlsson, Mr. Frans Olof                                 1    male  33.0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)            1  female  56.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Behr, Mr. Karl Howell                                    1    male  26.0
#
#                                                     SibSp  Parch    Ticket  \
# Name
# ...

# %%
df.dropna(axis = 1)
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# McCarthy, Mr. Timothy J                                  1    male  54.0
# Sandstrom, Miss. Marguerite Rut                          3  female   4.0
# Bonnell, Miss. Elizabeth                                 1  female  58.0
# Beesley, Mr. Lawrence                                    2    male  34.0
# ...                                                    ...     ...   ...
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)         1  female  47.0
# Carlsson, Mr. Frans Olof                                 1    male  33.0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)            1  female  56.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Behr, Mr. Karl Howell                                    1    male  26.0
#
#                                                     SibSp  Parch    Ticket  \
# Name
# ...

# %% [markdown]
# # So We call the fresh data

# %%
pd.read_csv("titanic 2.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# now delete column which has missing value

# %%
z = pd.read_csv("titanic 2.csv")

# %%
z
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
z.dropna(axis = 1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %% [markdown]
# # so the missing column is deleted

# %% [markdown]
# ## to paste some datat at missing values

# %%
z
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
z.fillna("Sana")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
z
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
z.fillna("Sana", inplace = True)

# %%
z
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
